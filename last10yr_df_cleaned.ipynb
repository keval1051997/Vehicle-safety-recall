# %%
# Import dependencies
import pandas as pd
# Read in file
df = pd.read_csv('./resources/recalls.csv')

# %%
# Information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26590 entries, 0 to 26589
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Report Received Date  26590 non-null  object
#  1   NHTSA ID              26590 non-null  object
#  2   Recall Link           26590 non-null  object
#  3   Manufacturer          26590 non-null  object
#  4   Subject               26590 non-null  object
#  5   Component             26590 non-null  object
#  6   Mfr Campaign Number   26561 non-null  object
#  7   Recall Type           26590 non-null  object
#  8   Potentially Affected  26548 non-null  float64
#  9   Recall Description    24189 non-null  object
#  10  Consequence Summary   21702 non-null  object
#  11  Corrective Action     24202 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 2.4+ MB

# %%
# Find max length of all columns in df with 'object' dtype (string)
# Used to provide VARCHAR column limits when creating table schema
columns = list(df.select_dtypes(['object']).columns)
for column in columns:
    print(f'{column}: {df[column].str.len().max()}')
# Out:
# Report Received Date: 10
# NHTSA ID: 9
# Recall Link: 62
# Manufacturer: 40
# Subject: 50
# Component: 28
# Mfr Campaign Number: 20.0
# Recall Type: 10
# Recall Description: 1982.0
# Consequence Summary: 758.0
# Corrective Action: 1672.0

# %%
# Temporary dataframe to keep any rows with a null value (data exploration)
df1 = df[df.isna().any(axis=1)]

# %%
df1.head()
# Out:
#      Report Received Date   NHTSA ID  \
# 200            10/14/2022  22E088000
# 341            08/26/2022  22V647000
# 369            08/13/2022  22T013000
# 606            06/07/2022  22C002000
# 1056           12/23/2021  21E104000
#
#                                             Recall Link  \
# 200   Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 341   Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 369   Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 606   Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 1056  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                         Manufacturer  \
# 200                      SAF-Holland
# 341   Hino Motors Sales U.S.A., Inc.
# 369       Zhaoqing Junhong Co., Ltd.
# 606                       Clek, Inc.
# 1056      Crysteel Manufacturing Inc
#
#                                               Subject  \
# 200    Loose Brake Pad Retaining Clip May Damage Tire
# 341   Electrical Short Circuit May Cause Engine Stall
# 369                 Tire Belt May Separate/ FMVSS 139
# 606            Installation Diagram Missing/FMVSS 213
# 1056                       Hydraulic Cylinder Failure
#
#                       Component Mfr Campaign Number Recall Type  \
# 200         SERVICE BRAKES, AIR                 NaN   Equipment
# 341   ENGINE AND ENGINE COOLING                 NaN     Vehicle
# 369                       TIRES   NR (Not Reported)        Tire
# 606                  CHILD SEAT                 NaN  Child Seat
# 1056                  EQUIPMENT                 NaN   Equipment
#
#       Potentially Affected                                 Recall Description  \
# 200                10591.0  SAF-Holland is recalling certain ULX40 Suspens...
# 341                    7.0  Hino Motors Sales U.S.A., Inc. (Hino) is recal...
# 369                    NaN  Zhaoqing Junhong Co., Ltd. (Zhaoquing) is reca...
# 606                11123.0  Clek, Inc. (Clek) is recalling certain Olli bo...
# 1056                 261.0  Crysteel Manufacturing Inc. (Crysteel) is reca...
#
#                                     Consequence Summary  \
# 200   A retaining clip or bracket that detaches can ...
# 341   An unexpected engine shut down can increase th...
# 369   Belt separation may lead to loss of vehicle co...
# 606   A missing installation label may result in an ...
# 1056  Cylinder detachment can contact the cab and ca...
#
#                                       Corrective Action
# 200   Dealers will inspect and repair the spring bra...
# 341   Dealers will replace the ECM, free of charge. ...
# 369   Dealers will inspect times to confirm the prod...
# 606   Clek will mail owners a new label, free of cha...
# 1056  Crysteel will replace the cylinder, free of ch...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4996 entries, 200 to 26589
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Report Received Date  4996 non-null   object
#  1   NHTSA ID              4996 non-null   object
#  2   Recall Link           4996 non-null   object
#  3   Manufacturer          4996 non-null   object
#  4   Subject               4996 non-null   object
#  5   Component             4996 non-null   object
#  6   Mfr Campaign Number   4967 non-null   object
#  7   Recall Type           4996 non-null   object
#  8   Potentially Affected  4954 non-null   float64
#  9   Recall Description    2595 non-null   object
#  10  Consequence Summary   108 non-null    object
#  11  Corrective Action     2608 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 507.4+ KB

# %%
# Drop rows with null values in specific column
df.dropna(subset=['Mfr Campaign Number'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26561 entries, 0 to 26589
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Report Received Date  26561 non-null  object
#  1   NHTSA ID              26561 non-null  object
#  2   Recall Link           26561 non-null  object
#  3   Manufacturer          26561 non-null  object
#  4   Subject               26561 non-null  object
#  5   Component             26561 non-null  object
#  6   Mfr Campaign Number   26561 non-null  object
#  7   Recall Type           26561 non-null  object
#  8   Potentially Affected  26519 non-null  float64
#  9   Recall Description    24160 non-null  object
#  10  Consequence Summary   21673 non-null  object
#  11  Corrective Action     24173 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 2.6+ MB

# %%
# Continuation of dropping rows with null values
df.dropna(subset=['Potentially Affected'], inplace=True)
df.dropna(subset=['Recall Description'], inplace=True)
df.dropna(subset=['Consequence Summary'], inplace=True)
df.dropna(subset=['Corrective Action'], inplace=True)

# %%
# Confirming all df values are not null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21594 entries, 0 to 26586
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Report Received Date  21594 non-null  object
#  1   NHTSA ID              21594 non-null  object
#  2   Recall Link           21594 non-null  object
#  3   Manufacturer          21594 non-null  object
#  4   Subject               21594 non-null  object
#  5   Component             21594 non-null  object
#  6   Mfr Campaign Number   21594 non-null  object
#  7   Recall Type           21594 non-null  object
#  8   Potentially Affected  21594 non-null  float64
#  9   Recall Description    21594 non-null  object
#  10  Consequence Summary   21594 non-null  object
#  11  Corrective Action     21594 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 2.1+ MB

# %%
list(df.columns)
# Out:
# ['Report Received Date',
#  'NHTSA ID',
#  'Recall Link',
#  'Manufacturer',
#  'Subject',
#  'Component',
#  'Mfr Campaign Number',
#  'Recall Type',
#  'Potentially Affected',
#  'Recall Description',
#  'Consequence Summary',
#  'Corrective Action']

# %%
# String replacement of single quotes to blank (data has both single and double quotes)
# to resolve postgres import error
for column in columns:
    df[column] = df[column].str.replace('\'','', regex=True)

# %%
# First iteration of cleaned data (no null values, string replacement)
df.to_csv('./resources/recalls_dropna.csv', index=False)

# %% [markdown]
# ### Additional Data Exploration

# %%
import pandas as pd
df = pd.read_csv('./resources/recalls_dropna.csv')
df.head()
# Out:
#   Report Received Date   NHTSA ID  \
# 0           01/06/2023  23V002000
# 1           01/05/2023  23V001000
# 2           12/29/2022  22V956000
# 3           12/29/2022  22V957000
# 4           12/29/2022  22E102000
#
#                                          Recall Link  \
# 0  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 1  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 2  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 3  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 4  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                         Manufacturer  \
# 0     Triple E Recreational Vehicles
# 1                 Volvo Car USA, LLC
# 2  Volkswagen Group of America, Inc.
# 3          Indian Motorcycle Company
# 4            Hendrickson USA. L.L.C.
#
#                                           Subject            Component  \
# 0             Battery Disconnect Switch May Short    ELECTRICAL SYSTEM
# 1                      Steering Wheel May Lock Up             STEERING
# 2         12-Volt Battery Cable May Short Circuit    ELECTRICAL SYSTEM
# 3    Kickstand May Not Retract Properly/FMVSS 123            STRUCTURE
# 4  Loose Brake Pad Retaining Clip May Damage Tire  SERVICE BRAKES, AIR
#
#   Mfr Campaign Number Recall Type  Potentially Affected  \
# 0          CA#10253-1     Vehicle                 341.0
# 1              R10213     Vehicle                  74.0
# 2                97HA     Vehicle                1042.0
# 3             I-23-01     Vehicle                4653.0
# 4   NR (Not Reported)   Equipment                  12.0
#
#                                   Recall Description  \
# 0  Triple E Recreational Vehicles (Triple E) is r...
# 1  Volvo Car USA, LLC (Volvo Car) is recalling ce...
# 2  Volkswagen Group of America, Inc. (Volkswagen)...
# 3  Indian Motorcycle Company (Indian) is recallin...
# 4  Hendrickson USA, L.L.C. (Hendrickson) is recal...
#
#                                  Consequence Summary  \
# 0  An electrical short-circuit can increase the r...
# 1  A screw inside the gearbox housing can cause t...
# 2  A short circuit may cause a loss of drive powe...
# 3  A kickstand that does not properly retract can...
# 4  A retaining clip or bracket that detaches can ...
#
#                                    Corrective Action
# 0  Dealers will install two rubber terminal post ...
# 1  Dealers will replace the steering gear, free o...
# 2  Owners are advised to park outside and away fr...
# 3  The remedy is currently under development.  Ow...
# 4  All affected VanTraxx assemblies have been ins...

# %%
# Confirming 'NHSTA ID' column values are all unique
df['NHTSA ID'].nunique()
# Out:
# 21594

# %%
# Convert 'Report Received Date' to date format
df['Report Received Date'] = pd.to_datetime(df['Report Received Date'], format='%m/%d/%Y')

df.head()
# Out:
#   Report Received Date   NHTSA ID  \
# 0           2023-01-06  23V002000
# 1           2023-01-05  23V001000
# 2           2022-12-29  22V956000
# 3           2022-12-29  22V957000
# 4           2022-12-29  22E102000
#
#                                          Recall Link  \
# 0  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 1  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 2  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 3  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 4  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                         Manufacturer  \
# 0     Triple E Recreational Vehicles
# 1                 Volvo Car USA, LLC
# 2  Volkswagen Group of America, Inc.
# 3          Indian Motorcycle Company
# 4            Hendrickson USA. L.L.C.
#
#                                           Subject            Component  \
# 0             Battery Disconnect Switch May Short    ELECTRICAL SYSTEM
# 1                      Steering Wheel May Lock Up             STEERING
# 2         12-Volt Battery Cable May Short Circuit    ELECTRICAL SYSTEM
# 3    Kickstand May Not Retract Properly/FMVSS 123            STRUCTURE
# 4  Loose Brake Pad Retaining Clip May Damage Tire  SERVICE BRAKES, AIR
#
#   Mfr Campaign Number Recall Type  Potentially Affected  \
# 0          CA#10253-1     Vehicle                 341.0
# 1              R10213     Vehicle                  74.0
# 2                97HA     Vehicle                1042.0
# 3             I-23-01     Vehicle                4653.0
# 4   NR (Not Reported)   Equipment                  12.0
#
#                                   Recall Description  \
# 0  Triple E Recreational Vehicles (Triple E) is r...
# 1  Volvo Car USA, LLC (Volvo Car) is recalling ce...
# 2  Volkswagen Group of America, Inc. (Volkswagen)...
# 3  Indian Motorcycle Company (Indian) is recallin...
# 4  Hendrickson USA, L.L.C. (Hendrickson) is recal...
#
#                                  Consequence Summary  \
# 0  An electrical short-circuit can increase the r...
# 1  A screw inside the gearbox housing can cause t...
# 2  A short circuit may cause a loss of drive powe...
# 3  A kickstand that does not properly retract can...
# 4  A retaining clip or bracket that detaches can ...
#
#                                    Corrective Action
# 0  Dealers will install two rubber terminal post ...
# 1  Dealers will replace the steering gear, free o...
# 2  Owners are advised to park outside and away fr...
# 3  The remedy is currently under development.  Ow...
# 4  All affected VanTraxx assemblies have been ins...

# %%
import datetime as dt

# DF for last ten years (>=2012)
last10yr_df = df[df['Report Received Date'].dt.year >= 2012]
last10yr_df.info()
print(last10yr_df.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10128 entries, 0 to 10127
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Report Received Date  10128 non-null  datetime64[ns]
#  1   NHTSA ID              10128 non-null  object
#  2   Recall Link           10128 non-null  object
#  3   Manufacturer          10128 non-null  object
#  4   Subject               10128 non-null  object
#  5   Component             10128 non-null  object
#  6   Mfr Campaign Number   10128 non-null  object
#  7   Recall Type           10128 non-null  object
#  8   Potentially Affected  10128 non-null  float64
#  9   Recall Description    10128 non-null  object
#  10  Consequence Summary   10128 non-null  object
#  11  Corrective Action     10128 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 1.0+ MB
#       Report Received Date   NHTSA ID  \
# 10123           2012-01-06  12V004000
# 10124           2012-01-04  11E057000
# 10125           2012-01-04  12V002000
# 10126           2012-01-03  11V606000
# 10127           2012-01-03  12V001000
#
#                                              Recall Link  \
# 10123  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 10124  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 10125  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 10126  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 10127  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                                 Manufacturer  \
# 10123                 Chrysler (FCA US, LLC)
# 10124                            DEXTER AXLE
# 10125             New Flyer of America, Inc.
# 10126                Utilimaster Corporation
# 10127  Mitsubishi Motors North America, Inc.
#
#                                       Subject               Component  \
# 10123  TIRE PRESSURE MONITOR SYSTEM/FMVSS 138                   TIRES
# 10124                      E/H BRAKE ACTUATOR               EQUIPMENT
# 10125      INSTRUMENT CLUSTER SOFTWARE/PARKER       ELECTRICAL SYSTEM
# 10126   FMVSS 206/DOOR CLOSURE WARNING SYSTEM  LATCHES/LOCKS/LINKAGES
# 10127                       TURN SIGNAL LEVER       EXTERIOR LIGHTING
#
#       Mfr Campaign Number Recall Type  Potentially Affected  \
# 10123                 L43     Vehicle                 303.0
# 10124   NR (Not Reported)   Equipment                1713.0
# 10125             R11-026     Vehicle                 490.0
# 10126   NR (Not Reported)     Vehicle                9861.0
# 10127   NR (Not Reported)     Vehicle                  21.0
#
#                                       Recall Description  \
# 10123  CHRYSLER IS RECALLING CERTAIN MODEL YEAR 2012 ...
# 10124  DEXTER AXLE IS RECALLING CERTAIN ELECTRIC/HYDR...
# 10125  NEW FLYER IS RECALLING CERTAIN MODEL YEARS 200...
# 10126  Certain Utilimaster model year 2009 through 20...
# 10127  MITSUBISHI IS RECALLING CERTAIN MODEL YEAR 201...
#
#                                      Consequence Summary  \
# 10123  UNDERINFLATED TIRES CAN RESULT IN TIRE OVERLOA...
# 10124  THE E/H BRAKE ACTUATOR PROVIDES BRAKING POWER ...
# 10125  ENGINE SHUTDOWN WOULD RESULT IN LOSS OF VEHICL...
# 10126  Certain work trucks are not equipped with eith...
# 10127  THE TURN SIGNAL MAY CONTINUE TO SIGNAL AN INTE...
#
#                                        Corrective Action
# 10123  CHRYSLER WILL NOTIFY OWNERS AND DEALERS WILL R...
# 10124  DEXTER AXLE IS WORKING WITH THE INSTALLERS AND...
# 10125  NEW FLYER WILL REPROGRAM THE INSTRUMENT PANEL ...
# 10126  Utilimaster will notify owners, and dealers wi...
# 10127  DEALERS WILL INSPECT THE TURN SIGNAL LEVER AND...

# %%
# Count of all values in 'Component' column
last10yr_df['Component'].value_counts().sort_index(ascending=True)
# Out:
# AIR BAGS                         720
# BACK OVER PREVENTION              97
# CHILD SEAT                        61
# COMMUNICATION                      9
# ELECTRICAL SYSTEM               1204
# ELECTRONIC STABILITY CONTROL      53
# ENGINE                            94
# ENGINE AND ENGINE COOLING        363
# EQUIPMENT                       1871
# EQUIPMENT ADAPTIVE/MOBILITY      176
# EXTERIOR LIGHTING                425
# FORWARD COLLISION AVOIDANCE       20
# FUEL SYSTEM, DIESEL              148
# FUEL SYSTEM, GASOLINE            318
# FUEL SYSTEM, OTHER                93
# HYBRID PROPULSION SYSTEM          39
# INTERIOR LIGHTING                  6
# LANE DEPARTURE                     8
# LATCHES/LOCKS/LINKAGES           177
# OTHER                              8
# PARKING BRAKE                    126
# POWER TRAIN                      523
# SEAT BELTS                       326
# SEATS                            270
# SERVICE BRAKES                    79
# SERVICE BRAKES, AIR              237
# SERVICE BRAKES, ELECTRIC          16
# SERVICE BRAKES, HYDRAULIC        370
# STEERING                         498
# STRUCTURE                        505
# SUSPENSION                       515
# TBD                                1
# TIRES                            278
# TRACTION CONTROL SYSTEM            2
# TRAILER HITCHES                   77
# UNKNOWN OR OTHER                  13
# VEHICLE SPEED CONTROL             39
# VISIBILITY                       237
# VISIBILITY/WIPER                  13
# WHEELS                           113
# Name: Component, dtype: int64

# %%
components_list = list(last10yr_df['Component'].unique())
components_list.sort()
components_list
# Out:
# ['AIR BAGS',
#  'BACK OVER PREVENTION',
#  'CHILD SEAT',
#  'COMMUNICATION',
#  'ELECTRICAL SYSTEM',
#  'ELECTRONIC STABILITY CONTROL',
#  'ENGINE',
#  'ENGINE AND ENGINE COOLING',
#  'EQUIPMENT',
#  'EQUIPMENT ADAPTIVE/MOBILITY',
#  'EXTERIOR LIGHTING',
#  'FORWARD COLLISION AVOIDANCE',
#  'FUEL SYSTEM, DIESEL',
#  'FUEL SYSTEM, GASOLINE',
#  'FUEL SYSTEM, OTHER',
#  'HYBRID PROPULSION SYSTEM',
#  'INTERIOR LIGHTING',
#  'LANE DEPARTURE',
#  'LATCHES/LOCKS/LINKAGES',
#  'OTHER',
#  'PARKING BRAKE',
#  'POWER TRAIN',
#  'SEAT BELTS',
#  'SEATS',
#  'SERVICE BRAKES',
#  'SERVICE BRAKES, AIR',
#  'SERVICE BRAKES, ELECTRIC',
#  'SERVICE BRAKES, HYDRAULIC',
#  'STEERING',
#  'STRUCTURE',
#  'SUSPENSION',
#  'TBD',
#  'TIRES',
#  'TRACTION CONTROL SYSTEM',
#  'TRAILER HITCHES',
#  'UNKNOWN OR OTHER',
#  'VEHICLE SPEED CONTROL',
#  'VISIBILITY',
#  'VISIBILITY/WIPER',
#  'WHEELS']

# %% [markdown]
# #### To group similar values (rename):
# - 'ENGINE' and 'ENGINE AND ENGINE COOLING'?; done
# - 'EQUIPMENT' and 'EQUIPMENT ADAPTIVE/MOBILITY'?; done
# - 'FUEL SYSTEM, DIESEL', 'FUEL SYSTEM, GASOLINE', 'FUEL SYSTEM, OTHER'?; done
# - 'SERVICE BRAKES*' columns (4); done
# - 'OTHER' and 'UNKNOWN OR OTHER'?; done
# - 'VISIBILITY' and 'VISIBILITY/WIPER'?; done
# - 'TIRES' and 'WHEELS'? keep separate?; tires (278) are component of the wheels (113)
#
# #### To review info and rename to other similar value:
# - 'TBD'; done

# %%
last10yr_df[last10yr_df['Component']=='TBD']
# Out:
#      Report Received Date   NHTSA ID  \
# 6486           2016-06-02  16V397000
#
#                                             Recall Link  \
# 6486  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                  Manufacturer                                     Subject  \
# 6486  Tiffin Motorhomes, Inc.  Possible Steering Loss Due to Wrong Spacer
#
#      Component Mfr Campaign Number Recall Type  Potentially Affected  \
# 6486       TBD   NR (Not Reported)     Vehicle                 539.0
#
#                                      Recall Description  \
# 6486  Tiffin Motorhomes is recalling certain model y...
#
#                                     Consequence Summary  \
# 6486  The steering wheels connection to the front ax...
#
#                                       Corrective Action
# 6486  Tiffin will notify owners, and dealers will in...

# %%
# Change 'TBD' value to 'STEERING'
last10yr_df.loc[last10yr_df['Component']=='TBD','Component'] = 'STEERING'
last10yr_df.iloc[6486,:]
# Out:
# /Users/muthukrishnan/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Report Received Date                                  2016-06-02 00:00:00
# NHTSA ID                                                        16V397000
# Recall Link             Go to Recall (https://www.nhtsa.gov/recalls?nh...
# Manufacturer                                      Tiffin Motorhomes, Inc.
# Subject                        Possible Steering Loss Due to Wrong Spacer
# Component                                                        STEERING
# Mfr Campaign Number                                     NR (Not Reported)
# Recall Type                                                       Vehicle
# Potentially Affected                                                539.0
# Recall Description      Tiffin Motorhomes is recalling certain model y...
# Consequence Summary     The steering wheels connection to the front ax...
# Corrective Action       Tiffin will notify owners, and dealers will in...
# Name: 6486, dtype: object

# %%
# Change 'VISIBILITY/WIPER' to 'VISIBILITY'
last10yr_df.loc[last10yr_df['Component']=='VISIBILITY/WIPER', 'Component'] = 'VISIBILITY'

# Change 'OTHER' to 'UNKNOWN OR OTHER'
last10yr_df.loc[last10yr_df['Component']=='OTHER', 'Component'] = 'UNKNOWN OR OTHER'

# Change 'SERVICE BRAKES*' values to 'SERVICE BRAKES'
last10yr_df.loc[last10yr_df['Component']=='SERVICE BRAKES, AIR', 'Component'] = 'SERVICE BRAKES'
last10yr_df.loc[last10yr_df['Component']=='SERVICE BRAKES, ELECTRIC', 'Component'] = 'SERVICE BRAKES'
last10yr_df.loc[last10yr_df['Component']=='SERVICE BRAKES, HYDRAULIC', 'Component'] = 'SERVICE BRAKES'

# Change 'FUEL SYSTEM*' values to 'FUEL SYSTEM'
last10yr_df.loc[last10yr_df['Component']=='FUEL SYSTEM, DIESEL', 'Component'] = 'FUEL SYSTEM'
last10yr_df.loc[last10yr_df['Component']=='FUEL SYSTEM, GASOLINE', 'Component'] = 'FUEL SYSTEM'
last10yr_df.loc[last10yr_df['Component']=='FUEL SYSTEM, OTHER', 'Component'] = 'FUEL SYSTEM'

# Change 'ENGINE AND ENGINE COOLING' to 'ENGINE'
last10yr_df.loc[last10yr_df['Component']=='ENGINE AND ENGINE COOLING', 'Component'] = 'ENGINE'

# Change 'EQUIPMENT ADAPTIVE/MOBILITY' to 'EQUIPMENT'
last10yr_df.loc[last10yr_df['Component']=='EQUIPMENT ADAPTIVE/MOBILITY', 'Component'] = 'EQUIPMENT'

# %%
components_list = list(last10yr_df['Component'].unique())
components_list.sort()
components_list
# Out:
# ['AIR BAGS',
#  'BACK OVER PREVENTION',
#  'CHILD SEAT',
#  'COMMUNICATION',
#  'ELECTRICAL SYSTEM',
#  'ELECTRONIC STABILITY CONTROL',
#  'ENGINE',
#  'EQUIPMENT',
#  'EXTERIOR LIGHTING',
#  'FORWARD COLLISION AVOIDANCE',
#  'FUEL SYSTEM',
#  'HYBRID PROPULSION SYSTEM',
#  'INTERIOR LIGHTING',
#  'LANE DEPARTURE',
#  'LATCHES/LOCKS/LINKAGES',
#  'PARKING BRAKE',
#  'POWER TRAIN',
#  'SEAT BELTS',
#  'SEATS',
#  'SERVICE BRAKES',
#  'STEERING',
#  'STRUCTURE',
#  'SUSPENSION',
#  'TIRES',
#  'TRACTION CONTROL SYSTEM',
#  'TRAILER HITCHES',
#  'UNKNOWN OR OTHER',
#  'VEHICLE SPEED CONTROL',
#  'VISIBILITY',
#  'WHEELS']

# %%
# Count of all values in 'Component' column (cleaned)
last10yr_df['Component'].value_counts().sort_index(ascending=True)
# Out:
# AIR BAGS                         720
# BACK OVER PREVENTION              97
# CHILD SEAT                        61
# COMMUNICATION                      9
# ELECTRICAL SYSTEM               1204
# ELECTRONIC STABILITY CONTROL      53
# ENGINE                           457
# EQUIPMENT                       2047
# EXTERIOR LIGHTING                425
# FORWARD COLLISION AVOIDANCE       20
# FUEL SYSTEM                      559
# HYBRID PROPULSION SYSTEM          39
# INTERIOR LIGHTING                  6
# LANE DEPARTURE                     8
# LATCHES/LOCKS/LINKAGES           177
# PARKING BRAKE                    126
# POWER TRAIN                      523
# SEAT BELTS                       326
# SEATS                            270
# SERVICE BRAKES                   702
# STEERING                         499
# STRUCTURE                        505
# SUSPENSION                       515
# TIRES                            278
# TRACTION CONTROL SYSTEM            2
# TRAILER HITCHES                   77
# UNKNOWN OR OTHER                  21
# VEHICLE SPEED CONTROL             39
# VISIBILITY                       250
# WHEELS                           113
# Name: Component, dtype: int64

# %%
# data frame after dropping Recall link column.
last10yr_df_cleaned = last10yr_df.drop(['Recall Link'], axis = 1)
last10yr_df_cleaned
# Out:
#       Report Received Date   NHTSA ID                           Manufacturer  \
# 0               2023-01-06  23V002000         Triple E Recreational Vehicles
# 1               2023-01-05  23V001000                     Volvo Car USA, LLC
# 2               2022-12-29  22V956000      Volkswagen Group of America, Inc.
# 3               2022-12-29  22V957000              Indian Motorcycle Company
# 4               2022-12-29  22E102000                Hendrickson USA. L.L.C.
# ...                    ...        ...                                    ...
# 10123           2012-01-06  12V004000                 Chrysler (FCA US, LLC)
# 10124           2012-01-04  11E057000                            DEXTER AXLE
# 10125           2012-01-04  12V002000             New Flyer of America, Inc.
# 10126           2012-01-03  11V606000                Utilimaster Corporation
# 10127           2012-01-03  12V001000  Mitsubishi Motors North America, Inc.
#
#                                               Subject               Component  \
# 0                 Battery Disconnect Switch May Short       ELECTRICAL SYSTEM
# 1                          Steering Wheel May Lock Up                STEERING
# 2             12-Volt Battery Cable May Short Circuit       ELECTRICAL SYSTEM
# 3        Kickstand May Not Retract Properly/FMVSS 123               STRUCTURE
# 4      Loose Brake Pad Retaining Clip May Damage Tire          SERVICE BRAKES
# ...                                               ...                     ...
# 10123          TIRE PRESSURE MONITOR SYSTEM/FMVSS 138                   TIRES
# 10124                              E/H BRAKE ACTUATOR               EQUIPMENT
# 10125              INSTRUMENT CLUSTER SOFTWARE/PARKER       ELECTRICAL SYSTEM
# 10126           FMVSS 206/DOOR CLOSURE WARNING SYSTEM  LATCHES/LOCKS/LINKAGES
# 10127                               TURN SIGNAL LEVER       EXTERIOR LIGHTING
#
#       Mfr Campaign Number Recall Type  Potentially Affected  \
# 0              CA#10253-1     Vehicle                 341.0
# 1                  R10213     Vehicle                  74.0
# 2                    97HA     Vehicle                1042.0
# 3                 I-23-01     Vehicle                4653.0
# 4       NR (Not Reported)   Equipment                  12.0
# ...                   ...         ...                   ...
# 10123                 L43     Vehicle                 303.0
# 10124   NR (Not Reported)   Equipment                1713.0
# 10125             R11-026     Vehicle                 490.0
# 10126   NR (Not Reported)     Vehicle                9861.0
# 10127   NR (Not Reported)     Vehicle                  21.0
#
#                                       Recall Description  \
# 0      Triple E Recreational Vehicles (Triple E) is r...
# 1      Volvo Car USA, LLC (Volvo Car) is recalling ce...
# 2      Volkswagen Group of America, Inc. (Volkswagen)...
# 3      Indian Motorcycle Company (Indian) is recallin...
# 4      Hendrickson USA, L.L.C. (Hendrickson) is recal...
# ...                                                  ...
# 10123  CHRYSLER IS RECALLING CERTAIN MODEL YEAR 2012 ...
# 10124  DEXTER AXLE IS RECALLING CERTAIN ELECTRIC/HYDR...
# 10125  NEW FLYER IS RECALLING CERTAIN MODEL YEARS 200...
# 10126  Certain Utilimaster model year 2009 through 20...
# 10127  MITSUBISHI IS RECALLING CERTAIN MODEL YEAR 201...
#
#                                      Consequence Summary  \
# 0      An electrical short-circuit can increase the r...
# 1      A screw inside the gearbox housing can cause t...
# 2      A short circuit may cause a loss of drive powe...
# 3      A kickstand that does not properly retract can...
# 4      A retaining clip or bracket that detaches can ...
# ...                                                  ...
# 10123  UNDERINFLATED TIRES CAN RESULT IN TIRE OVERLOA...
# 10124  THE E/H BRAKE ACTUATOR PROVIDES BRAKING POWER ...
# 10125  ENGINE SHUTDOWN WOULD RESULT IN LOSS OF VEHICL...
# 10126  Certain work trucks are not equipped with eith...
# 10127  THE TURN SIGNAL MAY CONTINUE TO SIGNAL AN INTE...
#
#                                        Corrective Action
# 0      Dealers will install two rubber terminal post ...
# 1      Dealers will replace the steering gear, free o...
# 2      Owners are advised to park outside and away fr...
# 3      The remedy is currently under development.  Ow...
# 4      All affected VanTraxx assemblies have been ins...
# ...                                                  ...
# 10123  CHRYSLER WILL NOTIFY OWNERS AND DEALERS WILL R...
# 10124  DEXTER AXLE IS WORKING WITH THE INSTALLERS AND...
# 10125  NEW FLYER WILL REPROGRAM THE INSTRUMENT PANEL ...
# 10126  Utilimaster will notify owners, and dealers wi...
# 10127  DEALERS WILL INSPECT THE TURN SIGNAL LEVER AND...
#
# [10128 rows x 11 columns]

# %%
last10yr_df_cleaned['Subject'].nunique()
# Out:
# 7144

# %%
# shrunken data to last 10 year and cleaned 
last10yr_df_cleaned.to_csv('./resources/last10yr_df_cleaned.csv', index=False)
